# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Speech-Recognition'
# %ls
# Out:
# /content/drive/MyDrive/Speech-Recognition
#  best_model.h5   best_model.hdf5   input/  'Speech Recognition.ipynb'

# %% [markdown]
# # Lấy dữ liệu

# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings
warnings.filterwarnings("ignore")
train_audio_path = 'input/train_split/'
labels=os.listdir(train_audio_path)

remove_text = '.ipynb_checkpoints'
if remove_text in labels : 
  labels.remove('.ipynb_checkpoints')
size_test = len(labels)

# %%
#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,10))
index = np.arange(len(labels))
print(no_of_recordings)
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=24)
plt.ylabel('No of recordings', fontsize=24)
plt.xticks(index, labels, fontsize=24, rotation=0)
plt.title('No. of recordings for each command')
plt.show()
# Out:
# [50, 50, 50, 50, 50, 50, 50]

# %% [markdown]
# **Duration of recordings**
#
# Độ dài file ghi âm

# %% [markdown]
# # **Dữ liệu Train**

# %%
shape = 100

# %%
for label in labels:
  print(label)
  waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
  for wav in waves:
      samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
      samples = librosa.resample(samples, sample_rate, 8000)
      if(len(samples) <  24000) : 
          all_wave.append(samples)
          all_label.append(label)

# %%
def Calculate_Energy(data, frames, samplerate = 44100):
  '''
  Hàm tính toán năng lượng 
  '''
  data0 = [i**2 for i in data] 
  E = np.empty(1, dtype=np.int64)
  samplein10 = int(samplerate * 0.01)
  for i in range(frames):
      c = np.empty(1, dtype=np.int64)
      for j in range(samplein10):
          c = np.append(c, data0[i * samplein10 + j])
      c = np.delete(c, 0) # xoa junk value
      d = np.sum(c)
      E = np.append(E, d)
  E = np.delete(E, 0) # xoa junk value 
  return E

# %%
def Detect_Voice(E) :
  '''
  Hàm xác định tiếng nói dựa theo ngưỡng
  '''
  maxE = np.amax(E)
  E = E / maxE

  draw = [] 
  new_list = []
  nguong_y = 0.1
  check = 0
  for m in range(len(E)-3) :
    if E[m] > nguong_y and check==0 :
      a = True
      for i in range(m,m+3) :
          if (E[i] < nguong_y) :
              a = False
              break
      if (a == True) :
          draw.append(m)
          check=1
    elif E[m] < nguong_y and check==1 :
      a=True
      for i in range(m,m+3):
        if (E[i] > nguong_y):
            a=False
            break
      if(a==True):
          draw.append(m-1)
          check=0

  if len(draw) >= 2 :
    new_list = E[draw[0] : draw[-1]]
    max_length = shape 
    if (len(new_list) > max_length) :
      different = len(new_list) - max_length
      first_part = E[draw[0]:draw[1]]
      second_part = E[draw[1] + different + 1: draw[-1] + 1 ]    # để có thể lấy thêm thằng cuối       
      new_list =  np.concatenate((first_part, second_part))

    elif len(new_list) < max_length :
      different = len(new_list) - max_length
      list_choices = E[draw[1] : draw[1] + different ] 
      first_part = E[draw[0] : draw[1]]
      second_part = E[draw[1] + different + 1  : draw[-1] + 1]    # để có thể lấy thêm thằng cuối    
      new_list = np.concatenate((first_part,list_choices, second_part)) 

  return new_list

# %%
train_audio_path = 'input/train_split/'
all_wave = [] 
all_label = []

for label in labels:
  waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')] # get waves files
  for wav in waves:
    samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 44100) # 
    data  = []

    # đưa dữ liệu từ 2 kênh về 1 kênh
    if len(samples.shape) == 2:
        if samples.shape[1] !=  1 :
            for i in range(len(samples)):
                data.append(samples[i][1])
    else : 
        data = samples

    frames = (float)((len(data) / sample_rate))
    frames = (int)(frames*100)

    E = Calculate_Energy(data, frames) # tính năng lượng
    new_list =  Detect_Voice(E) 
                  
    if len(new_list) == shape :
      # dán nhãn 
      all_wave.append(new_list) , all_label.append(label)    
                                                                                                                                    , all_wave.append(new_list) , all_label.append(label) ,#all_wave.append(new_list), all_label.append(label) 
    else : 
      continue

# %% [markdown]
# Convert the output labels to integer

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)
y=np_utils.to_categorical(y, num_classes=len(labels))

classes
# Out:
# ['dừng lại',
#  'quay phải',
#  'quay trái',
#  'sang phải',
#  'sang trái',
#  'đi lui',
#  'đi tới']

# %% [markdown]
# ## Create input shape

# %%
input_shape = (shape,1)

# %%
all_wave = np.array(all_wave).reshape(-1,shape,1) # shape same with len of sample

# %% [markdown]
# ## Create Model

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

inputs = Input(shape=input_shape) # Input shape has len same with data
dropout_rate = 0.2

#First Conv1D layer
conv = Conv1D(8, kernel_size=5, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(2)(conv)
conv = Dropout(dropout_rate)(conv)

#Second Conv1D layer
conv = Conv1D(16,3, padding='valid', activation='relu', strides=1)(conv)
conv = Dropout(dropout_rate)(conv)

#Third Conv1D layer
conv = Conv1D(32, 2, padding='valid', activation='relu', strides=1)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)
#Dense Layer 1
conv = Dense(64, activation='relu')(conv)
conv = Dropout(dropout_rate)(conv)
#Dense Layer 2
conv = Dense(32, activation='relu')(conv)
conv = Dropout(dropout_rate)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 96, 8)             48
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 8)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 8)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 46, 16)            400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 46, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 45, 32)            1056
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 45, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1440)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                92224
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 96,039
# Trainable params: 96,039
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Validation Test

# %% [markdown]
# **Split into train and validation set**
#
# Train the model on 80% of the data and validate on the remaining 20%:
#
# Test size is 0.2 that means 20%

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.25, random_state=1, shuffle=True)

# %% [markdown]
# Early stopping and model checkpoints are the callbacks to stop training the neural network at the right time and to save the best model after every epoch:

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, 
                   patience= 20, min_delta=0.0001) # kết thúc sớm với 20 giá trị giống nhau thì ngắt
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', 
                     verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# ### **Train dữ liệu thu được**

# %%
history=model.fit(x_tr, y_tr ,epochs = 200, callbacks=[es,mc], batch_size = 8, validation_data=(x_val,y_val))
# Out:
# Epoch 1/200
# 61/61 [==============================] - 1s 9ms/step - loss: 1.9486 - accuracy: 0.1428 - val_loss: 1.9167 - val_accuracy: 0.1988
#
# Epoch 00001: val_accuracy improved from -inf to 0.19876, saving model to best_model.h5
# Epoch 2/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.8988 - accuracy: 0.2403 - val_loss: 1.8302 - val_accuracy: 0.3168
#
# Epoch 00002: val_accuracy improved from 0.19876 to 0.31677, saving model to best_model.h5
# Epoch 3/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.8267 - accuracy: 0.2598 - val_loss: 1.7865 - val_accuracy: 0.3043
#
# Epoch 00003: val_accuracy did not improve from 0.31677
# Epoch 4/200
# 61/61 [==============================] - 0s 6ms/step - loss: 1.7452 - accuracy: 0.3362 - val_loss: 1.7218 - val_accuracy: 0.4099
#
# Epoch 00004: val_accuracy improved from 0.31677 to 0.40994, saving model to best_model.h5
# Epoch 5/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.7184 - accuracy: 0.3459 - val_loss: 1.6799 - val_accuracy: 0.4161
#
# Epoch 00005: val_accuracy improved from 0.40994 to 0.41615, saving model to best_model.h5
# Epoch 6/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.5666 - accuracy: 0.4549 - val_loss: 1.6182 - val_accuracy: 0.4099
#
# Epoch 00006: val_accuracy did not improve from 0.41615
# Epoch 7/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.5286 - accuracy: 0.3969 - val_loss: 1.5844 - val_accuracy: 0.4472
#
# Epoch 00007: val_accuracy improved from 0.41615 to 0.44720, saving model to best_model.h5
# Epoch 8/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.5079 - accuracy: 0.4581 - val_loss: 1.4782 - val_accuracy: 0.4534
#
# Epoch 00008: val_accuracy improved from 0.44720 to 0.45342, saving model to best_model.h5
# Epoch 9/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.4637 - accuracy: 0.4616 - val_loss: 1.4639 - val_accuracy: 0.4472
#
# Epoch 00009: val_accuracy did not improve from 0.45342
# Epoch 10/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3521 - accuracy: 0.5165 - val_loss: 1.4172 - val_accuracy: 0.4845
#
# Epoch 00010: val_accuracy improved from 0.45342 to 0.48447, saving model to best_model.h5
# Epoch 11/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.3070 - accuracy: 0.5000 - val_loss: 1.3155 - val_accuracy: 0.4658
#
# Epoch 00011: val_accuracy did not improve from 0.48447
# Epoch 12/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.2481 - accuracy: 0.5065 - val_loss: 1.2707 - val_accuracy: 0.5342
#
# Epoch 00012: val_accuracy improved from 0.48447 to 0.53416, saving model to best_model.h5
# Epoch 13/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.1445 - accuracy: 0.5863 - val_loss: 1.2661 - val_accuracy: 0.5528
#
# Epoch 00013: val_accuracy improved from 0.53416 to 0.55280, saving model to best_model.h5
# Epoch 14/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.0605 - accuracy: 0.6069 - val_loss: 1.1560 - val_accuracy: 0.5590
#
# Epoch 00014: val_accuracy improved from 0.55280 to 0.55901, saving model to best_model.h5
# Epoch 15/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.0741 - accuracy: 0.6110 - val_loss: 1.1758 - val_accuracy: 0.5528
#
# Epoch 00015: val_accuracy did not improve from 0.55901
# Epoch 16/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.0277 - accuracy: 0.6181 - val_loss: 1.1413 - val_accuracy: 0.6087
#
# Epoch 00016: val_accuracy improved from 0.55901 to 0.60870, saving model to best_model.h5
# Epoch 17/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.0787 - accuracy: 0.5894 - val_loss: 1.0623 - val_accuracy: 0.6025
#
# Epoch 00017: val_accuracy did not improve from 0.60870
# Epoch 18/200
# 61/61 [==============================] - 0s 5ms/step - loss: 1.0219 - accuracy: 0.6130 - val_loss: 1.0753 - val_accuracy: 0.5776
#
# Epoch 00018: val_accuracy did not improve from 0.60870
# Epoch 19/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.9338 - accuracy: 0.6468 - val_loss: 1.0391 - val_accuracy: 0.6087
#
# Epoch 00019: val_accuracy did not improve from 0.60870
# Epoch 20/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.8412 - accuracy: 0.6870 - val_loss: 0.9688 - val_accuracy: 0.6273
#
# Epoch 00020: val_accuracy improved from 0.60870 to 0.62733, saving model to best_model.h5
# Epoch 21/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.8482 - accuracy: 0.6893 - val_loss: 0.9501 - val_accuracy: 0.7081
#
# Epoch 00021: val_accuracy improved from 0.62733 to 0.70807, saving model to best_model.h5
# Epoch 22/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.7924 - accuracy: 0.7074 - val_loss: 0.9156 - val_accuracy: 0.7019
#
# Epoch 00022: val_accuracy did not improve from 0.70807
# Epoch 23/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.7136 - accuracy: 0.7093 - val_loss: 0.8992 - val_accuracy: 0.7143
#
# Epoch 00023: val_accuracy improved from 0.70807 to 0.71429, saving model to best_model.h5
# Epoch 24/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.7594 - val_loss: 0.8904 - val_accuracy: 0.6957
#
# Epoch 00024: val_accuracy did not improve from 0.71429
# Epoch 25/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.7216 - accuracy: 0.7582 - val_loss: 0.8661 - val_accuracy: 0.6894
#
# Epoch 00025: val_accuracy did not improve from 0.71429
# Epoch 26/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.7087 - accuracy: 0.7280 - val_loss: 0.8410 - val_accuracy: 0.7205
#
# Epoch 00026: val_accuracy improved from 0.71429 to 0.72050, saving model to best_model.h5
# Epoch 27/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.7324 - accuracy: 0.7130 - val_loss: 0.8555 - val_accuracy: 0.6957
#
# Epoch 00027: val_accuracy did not improve from 0.72050
# Epoch 28/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.6595 - accuracy: 0.7947 - val_loss: 0.8321 - val_accuracy: 0.6957
#
# Epoch 00028: val_accuracy did not improve from 0.72050
# Epoch 29/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.6578 - accuracy: 0.7613 - val_loss: 0.8195 - val_accuracy: 0.7143
#
# Epoch 00029: val_accuracy did not improve from 0.72050
# Epoch 30/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5919 - accuracy: 0.7840 - val_loss: 0.7966 - val_accuracy: 0.7391
#
# Epoch 00030: val_accuracy improved from 0.72050 to 0.73913, saving model to best_model.h5
# Epoch 31/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5625 - accuracy: 0.8207 - val_loss: 0.7981 - val_accuracy: 0.7019
#
# Epoch 00031: val_accuracy did not improve from 0.73913
# Epoch 32/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5478 - accuracy: 0.7997 - val_loss: 0.7751 - val_accuracy: 0.7453
#
# Epoch 00032: val_accuracy improved from 0.73913 to 0.74534, saving model to best_model.h5
# Epoch 33/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5263 - accuracy: 0.7932 - val_loss: 0.7795 - val_accuracy: 0.7329
#
# Epoch 00033: val_accuracy did not improve from 0.74534
# Epoch 34/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5744 - accuracy: 0.8024 - val_loss: 0.7801 - val_accuracy: 0.7578
#
# Epoch 00034: val_accuracy improved from 0.74534 to 0.75776, saving model to best_model.h5
# Epoch 35/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5562 - accuracy: 0.8124 - val_loss: 0.7369 - val_accuracy: 0.7516
#
# Epoch 00035: val_accuracy did not improve from 0.75776
# Epoch 36/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5432 - accuracy: 0.8043 - val_loss: 0.7818 - val_accuracy: 0.7578
#
# Epoch 00036: val_accuracy did not improve from 0.75776
# Epoch 37/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4855 - accuracy: 0.8408 - val_loss: 0.7650 - val_accuracy: 0.7764
#
# Epoch 00037: val_accuracy improved from 0.75776 to 0.77640, saving model to best_model.h5
# Epoch 38/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4761 - accuracy: 0.8161 - val_loss: 0.8023 - val_accuracy: 0.7702
#
# Epoch 00038: val_accuracy did not improve from 0.77640
# Epoch 39/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5026 - accuracy: 0.8160 - val_loss: 0.8141 - val_accuracy: 0.7764
#
# Epoch 00039: val_accuracy did not improve from 0.77640
# Epoch 40/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.5656 - accuracy: 0.8036 - val_loss: 0.7780 - val_accuracy: 0.7640
#
# Epoch 00040: val_accuracy did not improve from 0.77640
# Epoch 41/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4707 - accuracy: 0.8269 - val_loss: 0.7458 - val_accuracy: 0.7950
#
# Epoch 00041: val_accuracy improved from 0.77640 to 0.79503, saving model to best_model.h5
# Epoch 42/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4733 - accuracy: 0.8088 - val_loss: 0.6825 - val_accuracy: 0.8261
#
# Epoch 00042: val_accuracy improved from 0.79503 to 0.82609, saving model to best_model.h5
# Epoch 43/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4063 - accuracy: 0.8534 - val_loss: 0.6554 - val_accuracy: 0.8261
#
# Epoch 00043: val_accuracy did not improve from 0.82609
# Epoch 44/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4068 - accuracy: 0.8495 - val_loss: 0.6649 - val_accuracy: 0.8075
#
# Epoch 00044: val_accuracy did not improve from 0.82609
# Epoch 45/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3204 - accuracy: 0.8902 - val_loss: 0.6942 - val_accuracy: 0.8137
#
# Epoch 00045: val_accuracy did not improve from 0.82609
# Epoch 46/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4049 - accuracy: 0.8371 - val_loss: 0.7059 - val_accuracy: 0.8075
#
# Epoch 00046: val_accuracy did not improve from 0.82609
# Epoch 47/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4616 - accuracy: 0.8607 - val_loss: 0.7417 - val_accuracy: 0.7888
#
# Epoch 00047: val_accuracy did not improve from 0.82609
# Epoch 48/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4286 - accuracy: 0.8146 - val_loss: 0.7472 - val_accuracy: 0.7950
#
# Epoch 00048: val_accuracy did not improve from 0.82609
# Epoch 49/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.4946 - accuracy: 0.8054 - val_loss: 0.6852 - val_accuracy: 0.8137
#
# Epoch 00049: val_accuracy did not improve from 0.82609
# Epoch 50/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3845 - accuracy: 0.8548 - val_loss: 0.6811 - val_accuracy: 0.7950
#
# Epoch 00050: val_accuracy did not improve from 0.82609
# Epoch 51/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3956 - accuracy: 0.8644 - val_loss: 0.6511 - val_accuracy: 0.8075
#
# Epoch 00051: val_accuracy did not improve from 0.82609
# Epoch 52/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3897 - accuracy: 0.8304 - val_loss: 0.7179 - val_accuracy: 0.7888
#
# Epoch 00052: val_accuracy did not improve from 0.82609
# Epoch 53/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3635 - accuracy: 0.8675 - val_loss: 0.7582 - val_accuracy: 0.7950
#
# Epoch 00053: val_accuracy did not improve from 0.82609
# Epoch 54/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3114 - accuracy: 0.8974 - val_loss: 0.6856 - val_accuracy: 0.8261
#
# Epoch 00054: val_accuracy did not improve from 0.82609
# Epoch 55/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2602 - accuracy: 0.9168 - val_loss: 0.7497 - val_accuracy: 0.8261
#
# Epoch 00055: val_accuracy did not improve from 0.82609
# Epoch 56/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.8901 - val_loss: 0.7594 - val_accuracy: 0.8012
#
# Epoch 00056: val_accuracy did not improve from 0.82609
# Epoch 57/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3249 - accuracy: 0.8797 - val_loss: 0.7736 - val_accuracy: 0.8075
#
# Epoch 00057: val_accuracy did not improve from 0.82609
# Epoch 58/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3656 - accuracy: 0.8891 - val_loss: 0.7526 - val_accuracy: 0.7826
#
# Epoch 00058: val_accuracy did not improve from 0.82609
# Epoch 59/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2879 - accuracy: 0.9002 - val_loss: 0.7325 - val_accuracy: 0.8012
#
# Epoch 00059: val_accuracy did not improve from 0.82609
# Epoch 60/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3363 - accuracy: 0.8799 - val_loss: 0.7376 - val_accuracy: 0.8137
#
# Epoch 00060: val_accuracy did not improve from 0.82609
# Epoch 61/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3718 - accuracy: 0.8562 - val_loss: 0.7616 - val_accuracy: 0.8323
#
# Epoch 00061: val_accuracy improved from 0.82609 to 0.83230, saving model to best_model.h5
# Epoch 62/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3103 - accuracy: 0.8957 - val_loss: 0.7092 - val_accuracy: 0.8323
#
# Epoch 00062: val_accuracy did not improve from 0.83230
# Epoch 63/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3149 - accuracy: 0.8818 - val_loss: 0.7246 - val_accuracy: 0.8137
#
# Epoch 00063: val_accuracy did not improve from 0.83230
# Epoch 64/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2710 - accuracy: 0.8944 - val_loss: 0.7776 - val_accuracy: 0.8137
#
# Epoch 00064: val_accuracy did not improve from 0.83230
# Epoch 65/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2914 - accuracy: 0.8841 - val_loss: 0.7322 - val_accuracy: 0.8199
#
# Epoch 00065: val_accuracy did not improve from 0.83230
# Epoch 66/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3501 - accuracy: 0.8978 - val_loss: 0.7968 - val_accuracy: 0.8323
#
# Epoch 00066: val_accuracy did not improve from 0.83230
# Epoch 67/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3461 - accuracy: 0.8845 - val_loss: 0.7748 - val_accuracy: 0.8261
#
# Epoch 00067: val_accuracy did not improve from 0.83230
# Epoch 68/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2799 - accuracy: 0.8829 - val_loss: 0.6837 - val_accuracy: 0.8323
#
# Epoch 00068: val_accuracy did not improve from 0.83230
# Epoch 69/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2384 - accuracy: 0.9308 - val_loss: 0.6463 - val_accuracy: 0.8509
#
# Epoch 00069: val_accuracy improved from 0.83230 to 0.85093, saving model to best_model.h5
# Epoch 70/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2510 - accuracy: 0.9107 - val_loss: 0.7081 - val_accuracy: 0.8323
#
# Epoch 00070: val_accuracy did not improve from 0.85093
# Epoch 71/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2886 - accuracy: 0.8940 - val_loss: 0.7629 - val_accuracy: 0.8385
#
# Epoch 00071: val_accuracy did not improve from 0.85093
# Epoch 72/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2593 - accuracy: 0.9148 - val_loss: 0.7199 - val_accuracy: 0.8137
#
# Epoch 00072: val_accuracy did not improve from 0.85093
# Epoch 73/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3184 - accuracy: 0.8981 - val_loss: 0.7834 - val_accuracy: 0.8447
#
# Epoch 00073: val_accuracy did not improve from 0.85093
# Epoch 74/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3088 - accuracy: 0.9090 - val_loss: 0.7490 - val_accuracy: 0.8199
#
# Epoch 00074: val_accuracy did not improve from 0.85093
# Epoch 75/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2685 - accuracy: 0.8978 - val_loss: 0.7340 - val_accuracy: 0.8385
#
# Epoch 00075: val_accuracy did not improve from 0.85093
# Epoch 76/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2082 - accuracy: 0.9404 - val_loss: 0.8754 - val_accuracy: 0.8447
#
# Epoch 00076: val_accuracy did not improve from 0.85093
# Epoch 77/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.3233 - accuracy: 0.9166 - val_loss: 0.7482 - val_accuracy: 0.8012
#
# Epoch 00077: val_accuracy did not improve from 0.85093
# Epoch 78/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2911 - accuracy: 0.8977 - val_loss: 0.8086 - val_accuracy: 0.8261
#
# Epoch 00078: val_accuracy did not improve from 0.85093
# Epoch 79/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2411 - accuracy: 0.9215 - val_loss: 0.7513 - val_accuracy: 0.8323
#
# Epoch 00079: val_accuracy did not improve from 0.85093
# Epoch 80/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2625 - accuracy: 0.9092 - val_loss: 0.7912 - val_accuracy: 0.8261
#
# Epoch 00080: val_accuracy did not improve from 0.85093
# Epoch 81/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1957 - accuracy: 0.9330 - val_loss: 0.7699 - val_accuracy: 0.8323
#
# Epoch 00081: val_accuracy did not improve from 0.85093
# Epoch 82/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2256 - accuracy: 0.9353 - val_loss: 0.8084 - val_accuracy: 0.8447
#
# Epoch 00082: val_accuracy did not improve from 0.85093
# Epoch 83/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2588 - accuracy: 0.9225 - val_loss: 0.8312 - val_accuracy: 0.8323
#
# Epoch 00083: val_accuracy did not improve from 0.85093
# Epoch 84/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2435 - accuracy: 0.9248 - val_loss: 0.8769 - val_accuracy: 0.8447
#
# Epoch 00084: val_accuracy did not improve from 0.85093
# Epoch 85/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2025 - accuracy: 0.9265 - val_loss: 0.8005 - val_accuracy: 0.8447
#
# Epoch 00085: val_accuracy did not improve from 0.85093
# Epoch 86/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1797 - accuracy: 0.9233 - val_loss: 0.7467 - val_accuracy: 0.8385
#
# Epoch 00086: val_accuracy did not improve from 0.85093
# Epoch 87/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2897 - accuracy: 0.9176 - val_loss: 0.7960 - val_accuracy: 0.8509
#
# Epoch 00087: val_accuracy did not improve from 0.85093
# Epoch 88/200
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.9213 - val_loss: 0.9121 - val_accuracy: 0.8323
#
# Epoch 00088: val_accuracy did not improve from 0.85093
# Epoch 89/200
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2790 - accuracy: 0.9180 - val_loss: 0.8155 - val_accuracy: 0.8634
#
# Epoch 00089: val_accuracy improved from 0.85093 to 0.86335, saving model to best_model.h5
# Epoch 00089: early stopping

# %% [markdown]
# ##Trực quan hóa dữ liệu sau khi Train/Test

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['accuracy'], label='train') 
pyplot.plot(history.history['val_accuracy'], label='test') 
pyplot.legend() 
pyplot.show()

# %% [markdown]
# # Test

# %% [markdown]
# ## **Loading the best model**

# %%
from keras.models import load_model
model=load_model('best_model.h5')

# %% [markdown]
# Define the function that predicts text for the given audio:

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,shape,1))  # same len of data
    index=np.argmax(prob[0])
    return classes[index]

# %% [markdown]
# ***Prediction*** :  Make predictions on the validation data: ( Dự đoán )

# %%
filepath='input/voice-commands/test'
waves = [f for f in os.listdir(filepath + '/') if f.endswith('.wav')]
for wav in waves:
    samples, sample_rate = librosa.load(filepath + '/' + wav, sr = 44100)
    data  = []
    if len(samples.shape) == 2:
        if samples.shape[1] !=  1 :
            for i in range(len(samples)):
                data.append(samples[i][1])
    else : 
        data = samples

    frames = (float)((len(samples) / sample_rate))
    frames = (int)(frames*100)

    E = Calculate_Energy(data, frames)
    new_list = Detect_Voice(E)
    if len(new_list) == shape : 
      file_predict = predict(new_list)             
      print(wav + " : " + file_predict)
    else:
      print("NO VOICE DETECT")
      continue
# Out:
# ditoi_tue_03.wav : đi tới
# dunglai_tue_05.wav : dừng lại
# sangphai_tue_05.wav : sang phải
# dilui_tue_06.wav : đi lui
# sangtrai_tue_03.wav : sang trái
# quayphai_tue_09.wav : quay phải
# quaytrai_tue_07.wav : quay trái
# dilui_DLN_05.wav : đi lui
# dunglai_DLN_06.wav : dừng lại
# ditoi_DLN_03.wav : đi tới
# quaytrai_DLN_04.wav : quay trái
# quayphai_DLN_04.wav : quay phải
# NO VOICE DETECT
# sangphai_DLN_06.wav : quay phải
# sangtrai_DLN_04.wav : sang trái
# ditoi_Dat_07.wav : đi tới
# dilui_Dat_10.wav : đi lui
# dunglai_Dat_04.wav : dừng lại
# quayphai_Dat_05.wav : quay phải
# quaytrai_Dat_05.wav : quay trái
# sangtrai_Dat_05.wav : sang trái
